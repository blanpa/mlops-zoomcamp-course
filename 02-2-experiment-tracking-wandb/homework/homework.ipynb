# %% [markdown]
# ## Weights & Biases workshop
#
# * Video: https://www.youtube.com/watch?v=yNyqFMwEyL4
# * Github repository: https://wandb.me/mlops-zoomcamp-github
#
#
# ## Homework with Weights & Biases
#
# The goal of this homework is to get familiar with Weights & Biases for experiment tracking, model management, hyperparameter optimization, and many more.
#
# Befor getting started with the homework, you need to have a Weights & Biases account. You can do so by visiting [wandb.ai/site](https://wandb.ai/site) and clicking on the **Sign Up** button.
#
# # Q1. Install the Package
#
# To get started with Weights & Biases you'll need to install the appropriate Python package.
#
# For this we recommend creating a separate Python environment, for example, you can use [conda environments](https://docs.conda.io/projects/conda/en/latest/user-guide/getting-started.html#managing-envs),
# and then install the package there with `pip` or `conda`.
#
# Following are the libraries you need to install:
#
# * `pandas`
# * `matplotlib`
# * `scikit-learn`
# * `pyarrow`
# * `wandb`
#
# Once you installed the package, run the command `wandb --version` and check the output.
#
# What's the version that you have?

# %%
# !wandb --version
# Out:
# wandb, version 0.15.3

# %% [markdown]
# # Q2. Download and preprocess the data
#
# We'll use the Green Taxi Trip Records dataset to predict the amount of tips for each trip.
#
# Download the data for January, February and March 2022 in parquet format from [here](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page).
#
# **Tip:** In case you're on [GitHub Codespaces](https://github.com/features/codespaces) or [gitpod.io](https://gitpod.io), you can open up the terminal and run the following commands to download the data:
#
# ```shell
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-03.parquet
# ```
#
# Use the script `preprocess_data.py` located in the folder [`homework-wandb`](homework-wandb) to preprocess the data.
#
# The script will:
#
# * initialize a Weights & Biases run.
# * load the data from the folder `<TAXI_DATA_FOLDER>` (the folder where you have downloaded the data),
# * fit a `DictVectorizer` on the training set (January 2022 data),
# * save the preprocessed datasets and the `DictVectorizer` to your Weights & Biases dashboard as an artifact of type `preprocessed_dataset`.
#
# Your task is to download the datasets and then execute this command:
#
# ```bash
# python preprocess_data.py \
#   --wandb_project <WANDB_PROJECT_NAME> \
#   --wandb_entity <WANDB_USERNAME> \
#   --raw_data_path <TAXI_DATA_FOLDER> \
#   --dest_path ./output
# ```
#
# Tip: go to `02-experiment-tracking/homework-wandb/` folder before executing the command and change the value of `<WANDB_PROJECT_NAME>` to the name of your Weights & Biases project, `<WANDB_USERNAME>` to your Weights & Biases username, and `<TAXI_DATA_FOLDER>` to the location where you saved the data.
#
# Once you navigate to the `Files` tab of your artifact on your Weights & Biases page, what's the size of the saved `DictVectorizer` file?
#
# * 54 kB
# * 154 kB
# * 54 MB
# * 154 MB

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet -P /data/
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet -P /data/
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-03.parquet -P /data/
# Out:
# --2023-06-06 20:02:54--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet
# Auflösen des Hostnamens d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net) … 143.204.101.63, 143.204.101.175, 143.204.101.20, ...
# Verbindungsaufbau zu d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|143.204.101.63|:443 … verbunden.
# HTTP-Anforderung gesendet, auf Antwort wird gewartet … 200 OK
# Länge: 1254291 (1,2M) [binary/octet-stream]
# /data: Keine Berechtigung
# /data/green_tripdata_2022-01.parquet: Datei oder Verzeichnis nicht gefunden
#
# Schreiben nach ‘/data/green_tripdata_2022-01.parquet’ nicht möglich (Erfolg).
# --2023-06-06 20:02:55--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet
# Auflösen des Hostnamens d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net) … 143.204.101.58, 143.204.101.20, 143.204.101.175, ...
# Verbindungsaufbau zu d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|143.204.101.58|:443 … verbunden.
# HTTP-Anforderung gesendet, auf Antwort wird gewartet … 200 OK
# Länge: 1428262 (1,4M) [binary/octet-stream]
# /data: Keine Berechtigung
# /data/green_tripdata_2022-02.parquet: Datei oder Verzeichnis nicht gefunden
#
# Schreiben nach ‘/data/green_tripdata_2022-02.parquet’ nicht möglich (Erfolg).
# --2023-06-06 20:02:57--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-03.parquet
# Auflösen des Hostnamens d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net) … 143.204.101.175, 143.204.101.58, 143.204.101.20, ...
# Verbindungsaufbau zu d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|143.204.101.175|:443 … verbunden.
# HTTP-Anforderung gesendet, auf Antwort wird gewartet … 200 OK
# Länge: 1615562 (1,5M) [binary/octet-stream]
# /data: Keine Berechtigung
# /data/green_tripdata_2022-03.parquet: Datei oder Verzeichnis nicht gefunden
#
# Schreiben nach ‘/data/green_tripdata_2022-03.parquet’ nicht möglich (Erfolg).

# %%
import wandb

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: blanpa. Use `wandb login --relogin` to force relogin

# %%
# !python preprocess_data.py \
  --wandb_project mlobs-zoomcamp-wandb-homework \
  --wandb_entity blanpa \
  --raw_data_path ./data/ \
  --dest_path ./output
# Out:
# wandb: Currently logged in as: blanpa. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_201741-971bkz8d
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run divine-armadillo-2
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/971bkz8d
# wandb: Adding directory to artifact (./output)... Done. 0.1s
# wandb: Waiting for W&B process to finish... (success).
# wandb: 🚀 View run divine-armadillo-2 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/971bkz8d
# wandb: Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_201741-971bkz8d/logs

# %%
# !ls -la output/dv.pkl
# Out:
# -rw-rw-r-- 1 pascal pascal 153660 Jun  6 20:17 output/dv.pkl

# %% [markdown]
# Answer: 154kB

# %% [markdown]
# # Q3. Train a model with Weights & Biases logging
#
# We will train a `RandomForestRegressor` (from Scikit-Learn) on the taxi dataset.
#
# We have prepared the training script `train.py` for this exercise, which can be also found in the folder `homework-wandb`.
#
# The script will:
#
# * initialize a Weights & Biases run.
# * load the preprocessed datasets by fetching them from the Weights & Biases artifact previously created,
# * train the model on the training set,
# * calculate the MSE score on the validation set and log it to Weights & Biases,
# * save the trained model and log it to Weights & Biases as a model artifact.
#
# Your task is to modify the script to enable to add Weights & Biases logging, execute the script and then check the Weights & Biases run UI to check that the experiment run was properly tracked.
#
# TODO 1: log `mse` to Weights & Biases under the key `"MSE"`
#
# TODO 2: log `regressor.pkl` as an artifact of type `model`, refer to the [official docs](https://docs.wandb.ai/guides/artifacts) in order to know more about logging artifacts.
#
# You can run the script using:
#
# ```bash
# python train.py \
#   --wandb_project <WANDB_PROJECT_NAME> \
#   --wandb_entity <WANDB_USERNAME> \
#   --data_artifact "<WANDB_USERNAME>/<WANDB_PROJECT_NAME>/NYC-Taxi:v0"
# ```
#
# Tip 1: You can find the artifact address under the `Usage` tab in the respective artifact's page.
#
# Tip 2: don't modify the hyperparameters of the model to make sure that the training will finish quickly.
#
# Once you have successfully ran the script, navigate the `Overview` section of the run in the Weights & Biases UI and scroll down to the `Configs`. What is the value of the `max_depth` parameter:
#
# * 4
# * 6
# * 8
# * 10

# %%
# !python train.py \
  --wandb_project mlobs-zoomcamp-wandb-homework \
  --wandb_entity blanpa \
  --data_artifact "blanpa/mlobs-zoomcamp-wandb-homework/NYC-Taxi:v0"
# Out:
# wandb: Currently logged in as: blanpa. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_203804-l1xhklam
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fine-eon-5
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/l1xhklam
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45398
# wandb:
# wandb: 🚀 View run fine-eon-5 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/l1xhklam
# wandb: Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_203804-l1xhklam/logs

# %% [markdown]
# max_depth:
#   desc: null
#   value: 10
# random_state:
#   desc: null
#   value: 0
# _wandb:
#   desc: null
#   value:
#     python_version: 3.9.16
#     cli_version: 0.15.3
#     framework: sklearn
#     is_jupyter_run: false
#     is_kaggle_kernel: false
#     start_time: 1686076684.929747
#     t:
#       1:
#       - 5
#       - 53
#       - 55
#       2:
#       - 5
#       - 53
#       - 55
#       3:
#       - 16
#       - 23
#       4: 3.9.16
#       5: 0.15.3
#       8:
#       - 5

# %% [markdown]
# Answer: 10

# %% [markdown]
# # Q4. Tune model hyperparameters
#
# Now let's try to reduce the validation error by tuning the hyperparameters of the `RandomForestRegressor` using [Weights & Biases Sweeps](https://docs.wandb.ai/guides/sweeps). We have prepared the script `sweep.py` for this exercise in the `homework-wandb` directory.
#
# Your task is to modify `sweep.py` to pass the parameters `n_estimators`, `min_samples_split` and `min_samples_leaf` from `config` to `RandomForestRegressor` inside the `run_train()` function. Then we will run the sweep to figure out not only the best best of hyperparameters for training our model, but also to analyze the most optimum trends in different hyperparameters. We can run the sweep using:
#
# ```bash
# python sweep.py \
#   --wandb_project <WANDB_PROJECT_NAME> \
#   --wandb_entity <WANDB_USERNAME> \
#   --data_artifact "<WANDB_USERNAME>/<WANDB_PROJECT_NAME>/NYC-Taxi:v0"
# ```
#
# This command will run the sweep for 5 iterations using the **Bayesian Optimization and HyperBand** method proposed by the paper [BOHB: Robust and Efficient Hyperparameter Optimization at Scale](https://arxiv.org/abs/1807.01774). You can take a look at the sweep on your Weights & Biases dashboard, take a look at the **Parameter Inportance Panel** and the **Parallel Coordinates Plot** to determine, and analyze which hyperparameter is the most important:
#
# * `max_depth`
# * `n_estimators`
# * `min_samples_split`
# * `min_samples_leaf`

# %%
# !python sweep.py \
  --wandb_project mlobs-zoomcamp-wandb-homework \
  --wandb_entity blanpa \
  --data_artifact "blanpa/mlobs-zoomcamp-wandb-homework/NYC-Taxi:v0"
# Out:
# Create sweep with ID: ukbn4kfy
# Sweep URL: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/ukbn4kfy
# wandb: Agent Starting Run: 7lla16st with config:
# wandb: 	max_depth: 13
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 7
# wandb: 	n_estimators: 18
# wandb: Currently logged in as: blanpa. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_205103-7lla16st
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run different-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/ukbn4kfy
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7lla16st
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44963
# wandb:
# wandb: 🚀 View run different-sweep-1 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7lla16st
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_205103-7lla16st/logs
# wandb: Agent Starting Run: nmmo2nwu with config:
# wandb: 	max_depth: 3
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 32
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_205130-nmmo2nwu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run autumn-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/ukbn4kfy
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/nmmo2nwu
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.47426
# wandb:
# wandb: 🚀 View run autumn-sweep-2 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/nmmo2nwu
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_205130-nmmo2nwu/logs
# wandb: Agent Starting Run: yh1rycbn with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 18
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_205152-yh1rycbn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run devoted-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/ukbn4kfy
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/yh1rycbn
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44905
# wandb:
# wandb: 🚀 View run devoted-sweep-3 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/yh1rycbn
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_205152-yh1rycbn/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: hoim86fg with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 10
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_205235-hoim86fg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run solar-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/ukbn4kfy
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/hoim86fg
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45492
# wandb:
# wandb: 🚀 View run solar-sweep-4 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/hoim86fg
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_205235-hoim86fg/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 6azevbdx with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 29
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_205309-6azevbdx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rose-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/ukbn4kfy
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/6azevbdx
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.448
# wandb:
# wandb: 🚀 View run rose-sweep-5 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/6azevbdx
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_205309-6azevbdx/logs

# %% [markdown]
# Answer: min_samples_leaf

# %%
# !python sweep.py \
  --wandb_project mlobs-zoomcamp-wandb-homework \
  --wandb_entity blanpa \
  --data_artifact "blanpa/mlobs-zoomcamp-wandb-homework/NYC-Taxi:v0"
# Out:
# Create sweep with ID: reaci26y
# Sweep URL: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: Agent Starting Run: 4c20juee with config:
# wandb: 	max_depth: 3
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 18
# wandb: Currently logged in as: blanpa. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210039-4c20juee
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run trim-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/4c20juee
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.474
# wandb:
# wandb: 🚀 View run trim-sweep-1 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/4c20juee
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210039-4c20juee/logs
# wandb: Agent Starting Run: 9vkvk7vv with config:
# wandb: 	max_depth: 7
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 35
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210101-9vkvk7vv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run soft-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/9vkvk7vv
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45653
# wandb:
# wandb: 🚀 View run soft-sweep-2 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/9vkvk7vv
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210101-9vkvk7vv/logs
# wandb: Agent Starting Run: m5iiyksz with config:
# wandb: 	max_depth: 2
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 43
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210131-m5iiyksz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run radiant-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/m5iiyksz
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.48422
# wandb:
# wandb: 🚀 View run radiant-sweep-3 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/m5iiyksz
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210131-m5iiyksz/logs
# wandb: Agent Starting Run: ft5m93j8 with config:
# wandb: 	max_depth: 7
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 37
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210153-ft5m93j8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dashing-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/ft5m93j8
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4545
# wandb:
# wandb: 🚀 View run dashing-sweep-4 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/ft5m93j8
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210153-ft5m93j8/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: gbliukh2 with config:
# wandb: 	max_depth: 13
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 41
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210230-gbliukh2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run honest-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/gbliukh2
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44873
# wandb:
# wandb: 🚀 View run honest-sweep-5 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/gbliukh2
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210230-gbliukh2/logs
# wandb: Agent Starting Run: fd1z78xy with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 33
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210302-fd1z78xy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run divine-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/fd1z78xy
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44634
# wandb:
# wandb: 🚀 View run divine-sweep-6 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/fd1z78xy
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210302-fd1z78xy/logs
# wandb: Agent Starting Run: hrw0jlb2 with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 19
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210352-hrw0jlb2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run kind-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/hrw0jlb2
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45159
# wandb:
# wandb: 🚀 View run kind-sweep-7 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/hrw0jlb2
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210352-hrw0jlb2/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 470cvpm5 with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 44
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210436-470cvpm5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lucky-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/470cvpm5
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44859
# wandb:
# wandb: 🚀 View run lucky-sweep-8 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/470cvpm5
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210436-470cvpm5/logs
# wandb: Agent Starting Run: qn1kfqgr with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 47
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210523-qn1kfqgr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run solar-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/qn1kfqgr
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44771
# wandb:
# wandb: 🚀 View run solar-sweep-9 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/qn1kfqgr
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210523-qn1kfqgr/logs
# wandb: Agent Starting Run: 5e82jzu7 with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 10
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210606-5e82jzu7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ethereal-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/5e82jzu7
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.46265
# wandb:
# wandb: 🚀 View run ethereal-sweep-10 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/5e82jzu7
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210606-5e82jzu7/logs
# wandb: Agent Starting Run: xfneykip with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 39
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210628-xfneykip
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tough-sweep-11
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/xfneykip
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44892
# wandb:
# wandb: 🚀 View run tough-sweep-11 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/xfneykip
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210628-xfneykip/logs
# wandb: Agent Starting Run: i7ywg0gc with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 41
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210700-i7ywg0gc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run quiet-sweep-12
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/i7ywg0gc
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44697
# wandb:
# wandb: 🚀 View run quiet-sweep-12 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/i7ywg0gc
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210700-i7ywg0gc/logs
# wandb: Agent Starting Run: owx44s5c with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 30
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210736-owx44s5c
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run copper-sweep-13
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/owx44s5c
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44658
# wandb:
# wandb: 🚀 View run copper-sweep-13 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/owx44s5c
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210736-owx44s5c/logs
# wandb: Agent Starting Run: b9fwqzkp with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 41
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210814-b9fwqzkp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run soft-sweep-14
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/b9fwqzkp
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45823
# wandb:
# wandb: 🚀 View run soft-sweep-14 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/b9fwqzkp
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210814-b9fwqzkp/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: c9eqsm46 with config:
# wandb: 	max_depth: 15
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 48
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210901-c9eqsm46
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run warm-sweep-15
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/c9eqsm46
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44701
# wandb:
# wandb: 🚀 View run warm-sweep-15 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/c9eqsm46
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210901-c9eqsm46/logs
# wandb: Agent Starting Run: 7lo9p232 with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 46
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_210944-7lo9p232
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run proud-sweep-16
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7lo9p232
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4474
# wandb:
# wandb: 🚀 View run proud-sweep-16 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7lo9p232
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_210944-7lo9p232/logs
# wandb: Agent Starting Run: vai14eau with config:
# wandb: 	max_depth: 18
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211026-vai14eau
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run likely-sweep-17
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/vai14eau
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4469
# wandb:
# wandb: 🚀 View run likely-sweep-17 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/vai14eau
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211026-vai14eau/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7zn4i006 with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 36
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211114-7zn4i006
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run kind-sweep-18
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7zn4i006
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44634
# wandb:
# wandb: 🚀 View run kind-sweep-18 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7zn4i006
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211114-7zn4i006/logs
# wandb: Agent Starting Run: rsc92eva with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 31
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211156-rsc92eva
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vital-sweep-19
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/rsc92eva
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4504
# wandb:
# wandb: 🚀 View run vital-sweep-19 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/rsc92eva
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211156-rsc92eva/logs
# wandb: Agent Starting Run: pyq7r5rz with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 37
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211237-pyq7r5rz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ancient-sweep-20
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/pyq7r5rz
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44666
# wandb:
# wandb: 🚀 View run ancient-sweep-20 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/pyq7r5rz
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211237-pyq7r5rz/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 680u3pd9 with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 14
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211328-680u3pd9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run peachy-sweep-21
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/680u3pd9
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45486
# wandb:
# wandb: 🚀 View run peachy-sweep-21 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/680u3pd9
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211328-680u3pd9/logs
# wandb: Agent Starting Run: muetj5jv with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 36
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211356-muetj5jv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run clear-sweep-22
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/muetj5jv
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44895
# wandb:
# wandb: 🚀 View run clear-sweep-22 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/muetj5jv
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211356-muetj5jv/logs
# wandb: Agent Starting Run: p1zgqdxn with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 32
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211434-p1zgqdxn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run toasty-sweep-23
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/p1zgqdxn
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44746
# wandb:
# wandb: 🚀 View run toasty-sweep-23 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/p1zgqdxn
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211434-p1zgqdxn/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: cdpo0dke with config:
# wandb: 	max_depth: 18
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 45
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211522-cdpo0dke
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run jolly-sweep-24
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/cdpo0dke
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44648
# wandb:
# wandb: 🚀 View run jolly-sweep-24 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/cdpo0dke
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211522-cdpo0dke/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 9w1try82 with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211616-9w1try82
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run super-sweep-25
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/9w1try82
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44659
# wandb:
# wandb: 🚀 View run super-sweep-25 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/9w1try82
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211616-9w1try82/logs
# wandb: Agent Starting Run: 3j41hc8h with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 38
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211659-3j41hc8h
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run exalted-sweep-26
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/3j41hc8h
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4466
# wandb:
# wandb: 🚀 View run exalted-sweep-26 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/3j41hc8h
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211659-3j41hc8h/logs
# wandb: Agent Starting Run: 2wsqyyc7 with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 7
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211737-2wsqyyc7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run scarlet-sweep-27
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/2wsqyyc7
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45017
# wandb:
# wandb: 🚀 View run scarlet-sweep-27 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/2wsqyyc7
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211737-2wsqyyc7/logs
# wandb: Agent Starting Run: 6eqis6s6 with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 49
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211821-6eqis6s6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run serene-sweep-28
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/6eqis6s6
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44662
# wandb:
# wandb: 🚀 View run serene-sweep-28 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/6eqis6s6
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211821-6eqis6s6/logs
# wandb: Agent Starting Run: 1b0bcgbr with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 44
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211910-1b0bcgbr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frosty-sweep-29
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/1b0bcgbr
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44603
# wandb:
# wandb: 🚀 View run frosty-sweep-29 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/1b0bcgbr
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211910-1b0bcgbr/logs
# wandb: Agent Starting Run: ad67x8sz with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_211954-ad67x8sz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fearless-sweep-30
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/ad67x8sz
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44693
# wandb:
# wandb: 🚀 View run fearless-sweep-30 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/ad67x8sz
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_211954-ad67x8sz/logs
# wandb: Agent Starting Run: rd1kx28e with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 49
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212036-rd1kx28e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run logical-sweep-31
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/rd1kx28e
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4489
# wandb:
# wandb: 🚀 View run logical-sweep-31 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/rd1kx28e
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212036-rd1kx28e/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: oxj1nr5j with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 48
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212204-oxj1nr5j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run devout-sweep-32
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/oxj1nr5j
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4555
# wandb:
# wandb: 🚀 View run devout-sweep-32 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/oxj1nr5j
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212204-oxj1nr5j/logs
# wandb: Agent Starting Run: rjqda1s8 with config:
# wandb: 	max_depth: 18
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 43
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212251-rjqda1s8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sage-sweep-33
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/rjqda1s8
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4464
# wandb:
# wandb: 🚀 View run sage-sweep-33 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/rjqda1s8
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212251-rjqda1s8/logs
# wandb: Agent Starting Run: oyy4t56o with config:
# wandb: 	max_depth: 18
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 8
# wandb: 	n_estimators: 49
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212334-oyy4t56o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run exalted-sweep-34
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/oyy4t56o
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44824
# wandb:
# wandb: 🚀 View run exalted-sweep-34 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/oyy4t56o
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212334-oyy4t56o/logs
# wandb: Agent Starting Run: 1m1b07iu with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212424-1m1b07iu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run bumbling-sweep-35
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/1m1b07iu
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45017
# wandb:
# wandb: 🚀 View run bumbling-sweep-35 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/1m1b07iu
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212424-1m1b07iu/logs
# wandb: Agent Starting Run: p215d2es with config:
# wandb: 	max_depth: 15
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 43
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212515-p215d2es
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fancy-sweep-36
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/p215d2es
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44644
# wandb:
# wandb: 🚀 View run fancy-sweep-36 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/p215d2es
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212515-p215d2es/logs
# wandb: Agent Starting Run: nu650k0p with config:
# wandb: 	max_depth: 18
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 40
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212548-nu650k0p
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lyric-sweep-37
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/nu650k0p
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44724
# wandb:
# wandb: 🚀 View run lyric-sweep-37 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/nu650k0p
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212548-nu650k0p/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 3qoamto3 with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 35
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212630-3qoamto3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run apricot-sweep-38
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/3qoamto3
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44601
# wandb:
# wandb: 🚀 View run apricot-sweep-38 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/3qoamto3
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212630-3qoamto3/logs
# wandb: Agent Starting Run: naj1t0nk with config:
# wandb: 	max_depth: 18
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212704-naj1t0nk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run giddy-sweep-39
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/naj1t0nk
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4469
# wandb:
# wandb: 🚀 View run giddy-sweep-39 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/naj1t0nk
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212704-naj1t0nk/logs
# wandb: Agent Starting Run: ojeixixp with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 48
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212742-ojeixixp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run worthy-sweep-40
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/ojeixixp
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44698
# wandb:
# wandb: 🚀 View run worthy-sweep-40 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/ojeixixp
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212742-ojeixixp/logs
# wandb: Agent Starting Run: dteuqgn8 with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 31
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212819-dteuqgn8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run olive-sweep-41
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/dteuqgn8
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4473
# wandb:
# wandb: 🚀 View run olive-sweep-41 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/dteuqgn8
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212819-dteuqgn8/logs
# wandb: Agent Starting Run: 5apjihm1 with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 39
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212853-5apjihm1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run smart-sweep-42
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/5apjihm1
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44687
# wandb:
# wandb: 🚀 View run smart-sweep-42 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/5apjihm1
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212853-5apjihm1/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 5yez5jrh with config:
# wandb: 	max_depth: 7
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 10
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_212949-5yez5jrh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run glorious-sweep-43
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/5yez5jrh
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45745
# wandb:
# wandb: 🚀 View run glorious-sweep-43 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/5yez5jrh
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_212949-5yez5jrh/logs
# wandb: Agent Starting Run: 6bu7eg71 with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 43
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213020-6bu7eg71
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sweepy-sweep-44
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/6bu7eg71
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44819
# wandb:
# wandb: 🚀 View run sweepy-sweep-44 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/6bu7eg71
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213020-6bu7eg71/logs
# wandb: Agent Starting Run: xrv1oos4 with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 9
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213115-xrv1oos4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run true-sweep-45
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/xrv1oos4
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44774
# wandb:
# wandb: 🚀 View run true-sweep-45 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/xrv1oos4
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213115-xrv1oos4/logs
# wandb: Agent Starting Run: pi0jjtak with config:
# wandb: 	max_depth: 16
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 46
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213220-pi0jjtak
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run young-sweep-46
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/pi0jjtak
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44678
# wandb:
# wandb: 🚀 View run young-sweep-46 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/pi0jjtak
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213220-pi0jjtak/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7abxbi84 with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 45
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213324-7abxbi84
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dandy-sweep-47
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7abxbi84
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44612
# wandb:
# wandb: 🚀 View run dandy-sweep-47 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/7abxbi84
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213324-7abxbi84/logs
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: s276n6mz with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 42
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213434-s276n6mz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run woven-sweep-48
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/s276n6mz
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44998
# wandb:
# wandb: 🚀 View run woven-sweep-48 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/s276n6mz
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213434-s276n6mz/logs
# wandb: Agent Starting Run: bob1iw5p with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 42
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213528-bob1iw5p
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run treasured-sweep-49
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/bob1iw5p
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4486
# wandb:
# wandb: 🚀 View run treasured-sweep-49 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/bob1iw5p
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213528-bob1iw5p/logs
# wandb: Agent Starting Run: klecsfdf with config:
# wandb: 	max_depth: 17
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 50
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213624-klecsfdf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run scarlet-sweep-50
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/klecsfdf
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44659
# wandb:
# wandb: 🚀 View run scarlet-sweep-50 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/klecsfdf
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213624-klecsfdf/logs
# wandb: Agent Starting Run: 53vxatb7 with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 3
# wandb: 	n_estimators: 11
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213728-53vxatb7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run neat-sweep-51
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/53vxatb7
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45813
# wandb:
# wandb: 🚀 View run neat-sweep-51 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/53vxatb7
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213728-53vxatb7/logs
# wandb: Agent Starting Run: 4mbzsa0j with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 8
# wandb: 	n_estimators: 42
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /home/pascal/Projects/my/mlops-zoomcamp/02-2-experiment-tracking-wandb/homework/wandb/run-20230606_213801-4mbzsa0j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frosty-sweep-52
# wandb: ⭐️ View project at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework
# wandb: 🧹 View sweep at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/sweeps/reaci26y
# wandb: 🚀 View run at https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/4mbzsa0j
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.44759
# wandb:
# wandb: 🚀 View run frosty-sweep-52 at: https://wandb.ai/blanpa/mlobs-zoomcamp-wandb-homework/runs/4mbzsa0j
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_213801-4mbzsa0j/logs

# %% [markdown]
# # Q5. Link the best model to the model registry
#
# Now that we have obtained the optimal set of hyperparameters and trained the best model, we can assume that we are ready to test some of these models in production. In this exercise, you'll create a model registry and link the best model from the Sweep to the model registry.
#
# First, you will need to create a Registered Model to hold all the candidate models for your particular modeling task. You can refer to [this section](https://docs.wandb.ai/guides/models/walkthrough#1-create-a-new-registered-model) of the official docs to learn how to create a registered model using the Weights & Biases UI.
#
# Once you have created the Registered Model successfully, you can navigate to the best run of your sweep, navigate to the model artifact created by the particular run, and click on the Link to Registry option from the UI. This would link the model artifact to the Registered Model. You can choose to add some suitable aliases for the Registered Model, such as `production`, `best`, etc.
#
# Now that the model artifact is linked to the Registered Model, which of these information do we see on the Registered Model UI?
#
# * Versioning
# * Metadata
# * Aliases
# * Metric (MSE)
# * Source run
# * All of these
# * None of these

# %% [markdown]
# Answer: All of these
